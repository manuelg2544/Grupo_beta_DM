# %% [markdown]
# # Expected number of background events

# %% [markdown]
# ## Objectives
#
# * **Estimate the total number of background events**
#
# * **Estimate the number of selected background events** in the energy enlarged window and **in the RoI**

# %% [markdown]
# ## Analysis
#
# We will use a *blind* data sample: data where the signal events have been removed by a selection, which we call the *blind* selection.
#
# The blind selection removes from the full data the signal events while retaining most of the background events.
#
# We will compute the efficiency of the *blind* selection on *simulated background samples*, that is: $\epsilon^k_b$ with $k = \mathrm{Bi}, \mathrm{Tl}$.
#
# We will estimate the number of background events in the *blind* sample, $n_b^k$ with $k = \mathrm{Bi}, \mathrm{Tl}$.

# %% [markdown]
# We estimate the number of background events in the RoI given the selection efficiency in the RoI, $\epsilon^k_{RoI}$:
#
# $$
# n^k_{RoI} = \frac{\epsilon^k_{RoI}}{\epsilon^k_{b}} n^k_b
# $$
#
# We also estimate the number of background events in the enlarged energy window, $\epsilon^k_E$:
#
# $$
# n^k_{E} = \frac{\epsilon^k_{E}}{\epsilon^k_{b}} n^k_b
# $$
#
# with $k = \mathrm{Bi}, \mathrm{Tl}$.

# %% [markdown]
# Remember the selection in the RoI region has the following cuts:
#
#         * sel_ntracks, sel_eblob2, sel_eroi
#
# While the selection in the enlarged energy window:
#
#         * sel_ntracks, sel_eblob2, sel_erange

# %% [markdown]
# ## Estimation of the background events in the blind sample
#
# We estimate the number of background events $n^\mathrm{Bi}_b, \, n^{\mathrm{Tl}}_b$ as the values that minimise the $-2 \log$ extended maximum likelihood.
#
# We first define the PDF of the energy, $E$, for each background sample, $g_k(E), \;\; k = \mathrm{Bi}, \mathrm{Tl}$, using *simulated data*.
#
# We combine the PDFs into an extended likelihood, $\mathcal{L}({\bf E} |{\bf n}_b)$, where ${\bf n}_b = (n^{\mathrm{Bi}}_b, n^{\mathrm{Tl}}_b)$, $n_b = n^{\mathrm{Bi}}_b + n^{\mathrm{Tl}}_b$, and ${\bf E}$ are the energies of the $m$ events in the blind sample, $E_i, \;\, i= 1, \dots, m$:
#
# $$
# \mathcal{L}({\bf E} | {\bf n}_b) =  g(m | n_b) \, \Pi_{i=1}^m \sum_k \frac{n^k_b}{n_b}  \, g_k(E_i)
# $$
#
# where $g(m | n_b)$ is the Poisson probability of observing $m$ events given a mean of $n_b$ blind events.
#
# Finally, we estimate the parameters $n^\mathrm{Bi}_b, \, n^{\mathrm{Tl}}_b$ by minimising:
#
# $$
# - 2 \log \mathcal{L}({\bf E} | {\bf n}_b).
# $$

# %% [markdown]
# ## Analysis
#
# ### Import modules

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy  as np
import tables as tb
import pandas as pd
import matplotlib.pyplot as plt

import scipy.stats     as stats  # statistics and Many PDFs 
#import scipy.optimize  as optimize # Minimize functions

import warnings
warnings.filterwarnings('ignore')

# %%
import os, sys
from pathlib import Path

# Find the project root: honours FANAL_ROOT env-var, otherwise walks up from cwd
_env = os.environ.get('FANAL_ROOT') or os.environ.get('USCFANALDIR')
if _env and Path(_env, 'data').is_dir():
    rootpath = str(Path(_env).resolve())
else:
    rootpath = str(next(p for p in [Path.cwd(), *Path.cwd().parents]
                        if (p / 'data').is_dir() and (p / 'ana').is_dir()))
if rootpath not in sys.path:
    sys.path.insert(0, rootpath)
print('Fanal root : ', rootpath)
# Out:
# Fanal root :  /home/daniel/GitHub/Grupo_beta_DM

# %%
import core.pltext  as pltext   # extensions for plotting histograms
import core.hfit    as hfit     # extension to fit histograms
import core.efit    as efit     # Fit Utilites - Includes Extend Likelihood Fit with composite PDFs
import core.utils   as ut       # generic utilities
import ana.fanal    as fn       # analysis functions specific to fanal
import ana.pltfanal as pltfn    # plotting for fanal

import collpars    as collpars # collaboration specific parameters
pltext.style()

# %% [markdown]
# ### Parameters

# %%
coll          = collpars.collaboration
sel_erange    = collpars.sel_erange
sel_eroi      = collpars.sel_eroi
eff_Bi_E      = collpars.eff_Bi_E
eff_Tl_E      = collpars.eff_Tl_E
eff_Bi_RoI    = collpars.eff_Bi_RoI
eff_Tl_RoI    = collpars.eff_Tl_RoI

print('Collaboration         : {:s}'.format(coll))
print('Energy range          : ({:6.3f}, {:6.3f}) MeV'.format(*sel_erange))
print('RoI    range          : ({:6.3f}, {:6.3f}) MeV'.format(*sel_eroi))
print('Bi eff in E range     : {:6.4f} %'.format(100.*eff_Bi_E))
print('Tl eff in E range     : {:6.4f} %'.format(100.*eff_Tl_E))
print('Bi eff in RoI         : {:6.4f} %'.format(100.*eff_Bi_RoI))
print('Tl eff in RoI         : {:6.4f} %'.format(100.*eff_Tl_RoI))
# Out:
# Collaboration         : new_beta
# Energy range          : ( 2.400,  2.700) MeV
# RoI    range          : ( 2.430,  2.480) MeV
# Bi eff in E range     : 9.4900 %
# Tl eff in E range     : 1.8500 %
# Bi eff in RoI         : 8.0800 %
# Tl eff in RoI         : 0.2180 %

# %% [markdown]
# ### Data

# %%
#dirpath = '/Users/hernando/docencia/master/Fisica_Particulas/USC-Fanal/data/'
filename = '/data/fanal_' + coll + '.h5'
print('Data path and filename : ', rootpath + filename)

mcbi       = pd.read_hdf(rootpath + filename, key = 'mc/bi214').fillna(0.)   # MC Bi
mctl       = pd.read_hdf(rootpath + filename, key = 'mc/tl208').fillna(0.)   # MC Tl
data_blind = pd.read_hdf(rootpath + filename, key = 'data/blind').fillna(0.) # blind data

mc_samples         = [mcbi, mctl]
sample_names       = ['Bi', 'Tl']
sample_names_latex = [r'$^{214}$Bi', r'$^{208}$Tl']
# Out:
# Data path and filename :  /home/daniel/GitHub/Grupo_beta_DM/data/fanal_new_beta.h5

# %% [markdown]
# ### Estimate blind selection efficiency in MC

# %%
# apply the blind selection to the mc samples to obtain blind mc samples

def efficiency(mask):
    return float(sum(mask)/len(mask))

mask_bi = fn.selection_blind(mcbi)
mask_tl = fn.selection_blind(mctl)

eff_Bi_blind = efficiency(mask_bi)
eff_Tl_blind = efficiency(mask_tl)

mc_blind_samples =  (mcbi[mask_bi], mctl[mask_tl])

print('Bi blind eff : {:6.4f} %'.format(100.*eff_Bi_blind))
print('Tl blind eff : {:6.4f} %'.format(100.*eff_Tl_blind))
# Out:
# Bi blind eff : 78.5375 %
# Tl blind eff : 70.7461 %

# %% [markdown]
# ## Energy distribution of the blind data and mc samples

# %%
def plot_energy(df, label = '', bins = 100):
    pltext.hist(df.E, bins, range = sel_erange, label = label, density = True, lw = 2)
    plt.xlabel('Energy (MeV)'); 

subplot = pltext.canvas(2)
subplot(1)
plot_energy(data_blind)
plt.title('blind data');

subplot(2)
for i, df in enumerate(mc_blind_samples):
    plot_energy(df, label = sample_names_latex[i])

plt.legend(); plt.title('MC blind samples');

# %% [markdown]
# ## Estimate the number of background events in the blind-data

# %% [markdown]
# Estimate the number of events of Bi and Tl:
#
#   * Obtain the pdfs distribution for a reference variable, i.e. energy, for each blind sample.
#
#   * Generate a combined pdf where the parameters are the number of events of each sample.
#
#   * Estimate the number of blind Tl and Bi events fitting the energy distribution to the combined pdf.
#
#   * Compute the total number of Tl and Bi using the efficiencies of the blind selection in the MC samples.

# %%
nguess = (1000., 1000.)

varname   = 'E'
refnames  = (varname,) 
refranges = (sel_erange,)

fit        = fn.prepare_fit_ell(mc_blind_samples, nguess, refnames, refranges)

result, enes, ell, _ = fit(data_blind)
nevts_blind          = result.x

pltfn.plot_fit_ell(enes, nevts_blind, ell, parnames = sample_names_latex);

# %% [markdown]
# ### Compute the total number of background events

# %%
n_Bi_blind = nevts_blind[0]
n_Tl_blind = nevts_blind[1]

print(' number of blind events Bi : {:6.3f}'.format(n_Bi_blind))
print(' number of blind events Tl : {:6.3f}'.format(n_Tl_blind))
# Out:
#  number of blind events Bi : 1102.060
#  number of blind events Tl : 14627.127

# %% [markdown]
# ### Number of background events in RoI and E range
#
# *Exercise* Compute the number of bkg events for each sample in the Energy range and in RoI

# %%
# Compute the total number of Bi and Tl events, and the expected
# number of events in the energy range and in the RoI.
#
# Use the formulas:
#   n_k_total = n_k_blind / eff_k_blind
#   n_k_E     = n_k_total * eff_k_E
#   n_k_RoI   = n_k_total * eff_k_RoI
#
# where k = Bi, Tl
# YOUR CODE HERE

# Talio

n_k_total = n_Tl_blind / eff_Tl_blind
n_Tl_E     = n_k_total * eff_Tl_E
n_Tl_RoI   = n_k_total * eff_Tl_RoI


# Bismuto

n_k_total = n_Bi_blind / eff_Bi_blind
n_Bi_E     = n_k_total * eff_Bi_E
n_Bi_RoI   = n_k_total * eff_Bi_RoI

# %%
import numpy as np
from scipy.stats import gaussian_kde
from scipy.optimize import minimize_scalar

# =========================================================
# 1) Muestras MC
# =========================================================

df_Tl = mc_blind_samples[0]
df_Bi = mc_blind_samples[1]

# =========================================================
# 2) Conteos pedidos
# =========================================================

n_Tl_total = len(df_Tl)
n_Bi_total = len(df_Bi)

E_min = data_blind["E"].min()
E_max = data_blind["E"].max()

n_Tl_E = df_Tl["E"].between(E_min, E_max).sum()
n_Bi_E = df_Bi["E"].between(E_min, E_max).sum()

roi_min = 2.44
roi_max = 2.48

n_Tl_RoI = df_Tl["E"].between(roi_min, roi_max).sum()
n_Bi_RoI = df_Bi["E"].between(roi_min, roi_max).sum()

print(f"n_Tl_total = {n_Tl_total}")
print(f"n_Bi_total = {n_Bi_total}")
print(f"n_Tl_E     = {n_Tl_E}")
print(f"n_Bi_E     = {n_Bi_E}")
print(f"n_Tl_RoI   = {n_Tl_RoI}")
print(f"n_Bi_RoI   = {n_Bi_RoI}")

# =========================================================
# 3) KDEs de las PDFs de energía
# =========================================================

E_Tl = df_Tl["E"].to_numpy()
E_Bi = df_Bi["E"].to_numpy()
E_data = data_blind["E"].to_numpy()

kde_Tl = gaussian_kde(E_Tl)
kde_Bi = gaussian_kde(E_Bi)

eps = 1e-300
m = len(E_data)

# MUY IMPORTANTE:
# evaluar las KDE una sola vez sobre los datos
f_Tl_data = np.clip(kde_Tl(E_data), eps, None)
f_Bi_data = np.clip(kde_Bi(E_data), eps, None)

# =========================================================
# 4) Likelihood reducida a 1 parámetro
#
# Sea p = fracción de Tl
# entonces:
#   nb_Tl = p*m
#   nb_Bi = (1-p)*m
#
# porque en el máximo de la extended likelihood:
#   nb_Tl + nb_Bi = m
# =========================================================

def neg_log_likelihood_p(p):
    if p <= 0.0 or p >= 1.0:
        return np.inf

    model = p * f_Tl_data + (1.0 - p) * f_Bi_data
    model = np.clip(model, eps, None)

    # constantes omitidas: no afectan al mínimo
    return -np.sum(np.log(model))

# =========================================================
# 5) Ajuste rápido 1D
# =========================================================

result = minimize_scalar(
    neg_log_likelihood_p,
    bounds=(1e-12, 1 - 1e-12),
    method="bounded"
)

p_Tl_fit = result.x
p_Bi_fit = 1.0 - p_Tl_fit

nb_Tl_fit = m * p_Tl_fit
nb_Bi_fit = m * p_Bi_fit

print("\nResultado del ajuste:")
print("success =", result.success)
print("message =", result.message)
print(f"p_Tl  = {p_Tl_fit:.6f}")
print(f"p_Bi  = {p_Bi_fit:.6f}")
print(f"nb_Tl = {nb_Tl_fit:.6f}")
print(f"nb_Bi = {nb_Bi_fit:.6f}")
print(f"nb    = {nb_Tl_fit + nb_Bi_fit:.6f}")
# Out:
# n_Tl_total = 47267
# n_Bi_total = 486236
# n_Tl_E     = 47267
# n_Bi_E     = 486236
# n_Tl_RoI   = 36225
# n_Bi_RoI   = 46957
#
# Resultado del ajuste:
# success = True
# message = Solution found.
# p_Tl  = 0.334019
# p_Bi  = 0.665981
# nb_Tl = 7203.457832
# nb_Bi = 14362.542168
# nb    = 21566.000000

# %% [markdown]
# ### Notation-to-code reference
#
# | Math | Python variable | Description |
# |------|-----------------|-------------|
# | — | `exposure` | Detector exposure (kg $\cdot$ y) |
# | — | `acc_bb` | Signal acceptance |
# | $\epsilon^\mathrm{Bi}_b$ | `eff_Bi_blind` | $^{214}$Bi blind selection efficiency |
# | $\epsilon^\mathrm{Tl}_b$ | `eff_Tl_blind` | $^{208}$Tl blind selection efficiency |
# | $n^\mathrm{Bi}_b$ | `n_Bi_blind` | $^{214}$Bi events in blind sample |
# | $n^\mathrm{Tl}_b$ | `n_Tl_blind` | $^{208}$Tl events in blind sample |
# | $n^\mathrm{Bi}_\text{total}$ | `n_Bi_total` | Total $^{214}$Bi events ($= n^\mathrm{Bi}_b / \epsilon^\mathrm{Bi}_b$) |
# | $n^\mathrm{Tl}_\text{total}$ | `n_Tl_total` | Total $^{208}$Tl events ($= n^\mathrm{Tl}_b / \epsilon^\mathrm{Tl}_b$) |
# | $n^\mathrm{Bi}_E$ | `n_Bi_E` | $^{214}$Bi events in energy range ($= n^\mathrm{Bi}_\text{total} \cdot \epsilon^\mathrm{Bi}_E$) |
# | $n^\mathrm{Tl}_E$ | `n_Tl_E` | $^{208}$Tl events in energy range ($= n^\mathrm{Tl}_\text{total} \cdot \epsilon^\mathrm{Tl}_E$) |
# | $n^\mathrm{Bi}_{RoI}$ | `n_Bi_RoI` | $^{214}$Bi events in RoI ($= n^\mathrm{Bi}_\text{total} \cdot \epsilon^\mathrm{Bi}_{RoI}$) |
# | $n^\mathrm{Tl}_{RoI}$ | `n_Tl_RoI` | $^{208}$Tl events in RoI ($= n^\mathrm{Tl}_\text{total} \cdot \epsilon^\mathrm{Tl}_{RoI}$) |

# %%
import ana.fanal_display as fdisp

exposures  = {'new_alpha': 500, 'new_beta': 1000, 'new_gamma': 1000,
              'new_delta': 3000, 'new_epsilon': 3000}
acc_bb     = 0.79

exposure   = exposures[coll]

# Check your values before writing to collpars.py
fdisp.display_collpars([
    ('—',                          'exposure',     exposure,     '.2f'),
    ('—',                          'acc_bb',       acc_bb,       '.3f'),
    (r'\epsilon^\mathrm{Bi}_b',    'eff_Bi_blind', eff_Bi_blind, '.3f'),
    (r'\epsilon^\mathrm{Tl}_b',    'eff_Tl_blind', eff_Tl_blind, '.3f'),
    (r'n^\mathrm{Bi}_b',           'n_Bi_blind',   n_Bi_blind,   '.3f'),
    (r'n^\mathrm{Tl}_b',           'n_Tl_blind',   n_Tl_blind,   '.3f'),
    (r'n^\mathrm{Bi}_\text{total}','n_Bi_total',   n_Bi_total,   '.3f'),
    (r'n^\mathrm{Tl}_\text{total}','n_Tl_total',   n_Tl_total,   '.3f'),
    (r'n^\mathrm{Bi}_E',           'n_Bi_E',       n_Bi_E,       '.3f'),
    (r'n^\mathrm{Tl}_E',           'n_Tl_E',       n_Tl_E,       '.3f'),
    (r'n^\mathrm{Bi}_{RoI}',       'n_Bi_RoI',     n_Bi_RoI,     '.3f'),
    (r'n^\mathrm{Tl}_{RoI}',       'n_Tl_RoI',     n_Tl_RoI,     '.3f'),
])
# Out:
# <table style='border-collapse:collapse; margin:12px 0'><caption style='font-weight:bold; text-align:left; margin-bottom:6px'>Variables to write to collpars.py</caption><thead><tr><th style='border:1px solid #888; padding:4px 10px'>Math</th><th style='border:1px solid #888; padding:4px 10px'>Python variable</th><th style='border:1px solid #888; padding:4px 10px'>Your value</th></tr></thead><tbody><tr><td style='border:1px solid #888; padding:4px 10px'>$—$</td><td style='border:1px solid #888; padding:4px 10px'><code>exposure</code></td><td style='text-align:right'>1000</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$—$</td><td style='border:1px solid #888; padding:4px 10px'><code>acc_bb</code></td><td style='text-align:right'>0.790</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$\epsilon^\mathrm{Bi}_b$</td><td style='border:1px solid #888; padding:4px 10px'><code>eff_Bi_blind</code></td><td style='text-align:right'>0.785</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$\epsilon^\mathrm{Tl}_b$</td><td style='border:1px solid #888; padding:4px 10px'><code>eff_Tl_blind</code></td><td style='text-align:right'>0.707</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Bi}_b$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Bi_blind</code></td><td style='text-align:right'>1102.060</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Tl}_b$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Tl_blind</code></td><td style='text-align:right'>14627.127</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Bi}_\text{total}$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Bi_total</code></td><td style='text-align:right'>486236</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Tl}_\text{total}$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Tl_total</code></td><td style='text-align:right'>47267</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Bi}_E$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Bi_E</code></td><td style='text-align:right'>486236</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Tl}_E$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Tl_E</code></td><td style='text-align:right'>47267</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Bi}_{RoI}$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Bi_RoI</code></td><td style='text-align:right'>46957</td></tr>
# <tr><td style='border:1px solid #888; padding:4px 10px'>$n^\mathrm{Tl}_{RoI}$</td><td style='border:1px solid #888; padding:4px 10px'><code>n_Tl_RoI</code></td><td style='text-align:right'>36225</td></tr></tbody></table>

# %% [markdown]
# ## Write out
#
# We write out into the *collpars.py* file the number of events

# %%
exposures  = {'new_alpha': 500, 'new_beta': 1000, 'new_gamma': 1000,
              'new_delta': 3000, 'new_epsilon': 3000}
acc_bb     = 0.79

exposure   = exposures[coll]

write = True
if (write):
    of = open('collpars.py', 'a')
    of.write('exposure        = {:6.2f}'.format(exposure)+' # kg y \n')
    of.write('acc_bb          = {:6.3f}'.format(acc_bb)+'\n')

    of.write('eff_Bi_blind    = {:6.3f}'.format(eff_Bi_blind)+'\n')
    of.write('eff_Tl_blind    = {:6.3f}'.format(eff_Tl_blind)+'\n')

    of.write('n_Bi_total      = {:6.3f}'.format(n_Bi_total)+'\n')
    of.write('n_Bi_blind      = {:6.3f}'.format(n_Bi_blind)+'\n')
    of.write('n_Bi_E          = {:6.3f}'.format(n_Bi_E)+'\n')
    of.write('n_Bi_RoI        = {:6.3f}'.format(n_Bi_RoI)+'\n')

    of.write('n_Tl_total      = {:6.3f}'.format(n_Tl_total)+'\n')
    of.write('n_Tl_blind      = {:6.3f}'.format(n_Tl_blind)+'\n')
    of.write('n_Tl_E          = {:6.3f}'.format(n_Tl_E)+'\n')
    of.write('n_Tl_RoI        = {:6.3f}'.format(n_Tl_RoI)+'\n')
    of.close()
